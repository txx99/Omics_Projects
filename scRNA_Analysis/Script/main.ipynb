# %% [markdown]
# # scRNA Data Analysis in R
# Following [Arpudhamary V.'s](https://github.com/Marydoss-25/scRNA-Data-analysis-) tutorial for beginners in scRNA analysis, this notebook will learn to use the Seurat package and will perform:
#
# 1. data uploading
# 2. Seurat object conversion
# 3. QC
# 4. Filtering
# 5. Normalisation
# 6. ID highly variable genes
# 7. Data scaling
# 8. Dimensionality reduxn
# 9. Clustering
# 10. Non-linear dimensionality reduction
# 11. Cluster visualisation
